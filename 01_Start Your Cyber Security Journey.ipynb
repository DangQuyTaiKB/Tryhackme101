# %% [markdown]
# # 1. Offensive Security Intro
# Hack your first website (legally in a safe environment) and experience an ethical hacker's job.

# %% [markdown]
# ## Task 1: What is Offensive Security?
# Which of the following options better represents the process where you simulate a hacker's actions to find vulnerabilities in a system?
#
# - Offensive Security
# - Defensive Security
#
# Answer: Offensive Security

# %% [markdown]
# ## Task 2: Hacking your first machine
# #### Step 2. Use Gobuster To Find Hidden Website Pages
# - Open terminal from the right side of the machine and type in command: “gobuster -u http://fakebank.com -w wordlist.txt dir” in the terminal and hit “Enter”.
# > “gobuster” — Name of Command-Line Application or Utility we are using to brute-force the website and find out its hidden web-pages.
# > - gobuster -u http://fakebank.thm -w wordlist.txt dir
#
# > “-u” — Tag being used to set “http://fakebank.com” as target for the utility.
# >- Tag — All the characters or words before which we have “-”, are called as tags in the command. Tags are usually used to provide arguments to the utility.
# >- You can get a list of these tags for each utility by providing command “[Utility name] -h” in the terminal where “-h” usually stands for “help”.
#
# > “-w” — Tag being used to set “wordlist.txt” as wordlist for the utility.
# > - Wordlist — Wordlist is literally a list of words. Wordlists are usually used in scenarios where we have multiple possible options and the only option to get right answers is hit-and-trial method. A few scenarios can be brute-forcing a password, brute-forcing the directory (as in this task), dictionary attack, etc.
# > - rockyou.txt is a famous wordlist for password cracking. It comes with many other wordlists, built-in in Kali Linux.
#
# - “dir” — stands for “directory”. Directory in Linux is same as Folder in Windows.
#
# <img src="images/01_Start Your Cyber Security Journey/01_task2_img1.png" alt="Task 2 Directory" style="width: 50%; height: 50%;" />
#
#
# #### Step 3. Hack The Bank
# Execution of command shows we got two web-pages in the result of the operation we just performed i.e. /images and /bank-transfer. Let’s hop over these newly discovered web-pages by entering there URLs in the browser of the machine.
# P.S.: Web-pages we just discovered will be appended ahead of the main URL i.e. http://fakebank.com as http://fakebank.com/images and http://fakebank.com/bank-transfer.
#
# Whereas http://fakebank.com/bank-transfer hosts the “Admin Portal” for the bank site. This can be used to transfer the amount from one account to another. As we are tasked to transfer $2000 from the bank account 2276, to our account (account number 8881), thus this page would be of our ultimate use.
# Fill in the details as required by the task and click over “Send Money”.
#
# Once you’ll hit “Send Money”, you’ll be shown “Success, transfer complete” message with the particular details of the transaction you just performed.
# Hit “Return to Your Account” to find the answer of the first question in this task i.e. BANK-HACKED.
# Above your account balance, you should now see a message indicating the answer to this question. Can you find the answer you need?
# Flag: BANK-HACKED
#
# <img src="images/01_Start Your Cyber Security Journey/01_task2_img3.png" alt="Task 2 Directory" style="width: 50%; height: 50%;" />

# %% [markdown]
# ## Task 3: Careers in Cyber Security
#
# The cyber careers room goes into more depth about the different careers in cyber. However, here is a short description of a few offensive security roles:
#
# - Penetration Tester - Responsible for testing technology products for finding exploitable security vulnerabilities.
# - Red Teamer - Plays the role of an adversary, attacking an organization and providing feedback from an enemy's perspective.
# - Security Engineer - Design, monitor, and maintain security controls, networks, and systems to help prevent cyberattacks.

# %% [markdown]
# # 2. Defensive Security Intro
# Introducing defensive security and related topics, such as Threat Intelligence, SOC, DFIR, Malware Analysis, and SIEM.

# %% [markdown]
# ## Task 1: Introduction to Defensive Security
# In this task, we are introduced to two main tasks in Defensive Security:
#
# - Preventing intrusions from occuring
# - Detecting intrusions when they occur and responding properly
#
# - Which team focuses on defensive security?
# >- Answer: Blue Team
# >- Reason: As stated in the description of this task, “Blue team are part of the defensive security landscape.” On the other hand, Red team focuses on offensive security.

# %% [markdown]
# ## Task 2: Areas of Defensive Security
# In this task, we are being briefed regarding two main topics related to defensive security and one of their respective tasks:
# - Security Operations Center (SOC), covering Threat Intelligence
# - Digital Forensics and Incident Response (DFIR), covering Malware Analysis
#
# ### Security Operations Center (SOC)
# A Security Operations Center (SOC) is a team of cyber security professionals that monitors the network and its systems to detect malicious cyber security events.
# Key areas of focus:
# - Vulnerabilities: Identifying and mitigating system weaknesses
# - Policy Violations: Monitoring for non-compliance with security rules
# - Unauthorized Activity: Detecting and blocking unauthorized access attempts
# - Network Intrusions: Identifying and responding to network breaches
# - Threat Intelligence: Gathering and analyzing information about potential threats
#
# ### Threat Intelligence
# - Information about potential threats to a system or organization
# - Helps organizations prepare for and respond to cyberattacks
# - Involves collecting, processing, and analyzing data on threats and adversaries
# - Identifies potential threats and their tactics, techniques, and procedures
# - Enables organizations to implement proactive security measures and respond effectively to attacks
#
# ### Digital Forensics and Incident Response (DFIR)
#
# #### Digital Forensics
# - Application of scientific methods to investigate digital devices
# - Focuses on analyzing digital evidence to identify and prosecute cybercrimes
# - Key areas of investigation:
#     - File systems: Analyzing file systems for deleted, modified, or hidden data
#     - System memory: Examining memory dumps for active processes and malicious code
#     - System logs: Analyzing log files for system events, user activity, and security alerts
#     - Network traffic: Examining network traffic for suspicious activity and data exfiltration
#
# #### Incident Response
# - A systematic approach to handling security incidents
# - Involves identifying, analyzing, containing, eradicating, and recovering from security breaches
# - Key phases:
#     - Preparation: Developing incident response plans, training teams, and establishing procedures
#     - Detection and Analysis: Identifying and analyzing security incidents
#     - Containment, Eradication, and Recovery: Isolating infected systems, removing malware, and restoring systems to normal operation
#     - Post-Incident Activity: Documenting the incident, conducting lessons learned, and implementing corrective measures
#
# #### Malware Analysis
# - The process of examining malicious software to understand its behavior and functionality
# - Techniques:
#     - Static analysis: Examining malware code without executing it
#     - Dynamic analysis: Executing malware in a controlled environment to observe its behavior
# - Types of Malware
#     - Viruses: Self-replicating code that spreads through systems
#     - Worms: Self-propagating malware that spreads without human interaction
#     - Trojans: Malicious programs disguised as legitimate software
#     - Ransomware: Malware that encrypts data and demands a ransom for decryption
#     - Spyware: Malware that collects sensitive information without user consent
#
#
#
# > What would you call a team of cyber security professionals that monitors a network and its systems for malicious events?
# > - Security Operations Center. As stated in the description of this task, “A Security Operations Center (SOC) is a team of cyber security professionals that monitors the network and its systems to detect malicious cyber security events.”
#
# > What does DFIR stand for?
# > - Digital Forensics and Incident Response
#
# > Which kind of malware requires the user to pay money to regain access to their files?
# > - ransomware.As stated in the description of this task, “Ransomware is a malicious program that encrypts the user’s files. Encryption makes the files unreadable without knowing the encryption password. The attacker offers the user the encryption password if the user is willing to pay a ‘ransom’.”

# %% [markdown]
# ## Task 3: Practical Example of Defensive Security
#
# ## Scenario: SOC Analyst at a Bank
#
# **Role:** Security Operations Center (SOC) Analyst
# **Tool:** Security Information and Event Management (SIEM)
# **Task:** Monitor SIEM alerts and investigate potential threats
#
# **Challenges:**
# - False positives: Differentiating between legitimate and malicious activity
# - Unknown IP addresses: Identifying the source of connections and potential threats
# - Failed login attempts: Determining if they are accidental or malicious
#
# **Goal:** Protect the bank's systems and data from cyberattacks
#
# ### Simulating a SIEM
#
# - note down the suspected IP for further investigation i.e. 143.110.250.149.
#
# <img src="images/01_Start Your Cyber Security Journey/02_task3_img1.png" alt="Task 2 Directory" style="width: 50%; height: 50%;" />
#
# - Enter the suspected IP in the IP-SCANNER.THM to check the reputation of the IP address.
#
# <img src="images/01_Start Your Cyber Security Journey/02_task3_img2.png" alt="Task 2 Directory" style="width: 50%; height: 50%;" />
#
# - confirm that the suspected IP is “malicious”
#
# <img src="images/01_Start Your Cyber Security Journey/02_task3_img3.png" alt="Task 2 Directory" style="width: 50%; height: 50%;" />
#
# - As you have identified a security attack, it is the right time to escalate the event towards your team lead. You would be escalating the event to “SOC Team Lead” as you are a part of SOC team.
#
# <img src="images/01_Start Your Cyber Security Journey/02_task3_img4.png" alt="Task 2 Directory" style="width: 50%; height: 50%;" />
#
# - Once he allows you to block the malicious IP address you just found, type in the malicious IP address in Firewall Block List and hit “Block IP Address”.
#
# <img src="images/01_Start Your Cyber Security Journey/02_task3_img5.png" alt="Task 2 Directory" style="width: 50%; height: 50%;" />
#
# - Once the malicious IP address is blocked, you’ll be flashed your much awaiting flag i.e. THM{THREAT-BLOCKED}.
#
# <img src="images/01_Start Your Cyber Security Journey/02_task3_img6.png" alt="Task 2 Directory" style="width: 50%; height: 50%;" />
